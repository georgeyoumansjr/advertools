# %%
import advertools as adv

# %%
fb_robots = adv.robotstxt_to_df('https://www.facebook.com/robots.txt')
fb_robots
# Out:
# 2023-04-22 09:49:54,762 | INFO | robotstxt.py:381 | robotstxt_to_df | Getting: https://www.facebook.com/robots.txt
#       directive                                            content
# 0       comment  Notice: Collection of data on Facebook through...  \
# 1       comment  prohibited unless you have express written per...
# 2       comment  and may only be conducted for the limited purp...
# 3       comment                                        permission.
# 4       comment  See: http://www.facebook.com/apps/site_scrapin...
# ..          ...                                                ...
# 545       Allow  /ajax/pagelet/generic.php/PagePostsSectionPagelet
# 546       Allow                                          /careers/
# 547       Allow                                      /safetycheck/
# 548  User-agent                                                  *
# 549    Disallow                                                  /
#
# ...

# %% [markdown]
# fb_useragents = (fb_robots
#                  [fb_robots['directive']=='User-agent']
#                  ['content'].drop_duplicates()
#                 .tolist())
# fb_useragents

# %%
fb_useragents = (fb_robots
                 [fb_robots['directive']=='User-agent']
                 ['content'].drop_duplicates()
                .tolist())
fb_useragents
# Out:
# ['Applebot',
#  'baiduspider',
#  'Bingbot',
#  'Discordbot',
#  'facebookexternalhit',
#  'Googlebot',
#  'Googlebot-Image',
#  'ia_archiver',
#  'LinkedInBot',
#  'msnbot',
#  'Naverbot',
#  'Pinterestbot',
#  'Screaming Frog SEO Spider',
#  'seznambot',
#  'Slurp',
#  'teoma',
#  'TelegramBot',
#  'Twitterbot',
#  'Yandex',
#  'Yeti',
#  '*']

# %%
urls_to_test = ['/', '/bbc', '/groups', '/hashtag/']
fb_test = adv.robotstxt_test('https://www.facebook.com/robots.txt',
                         fb_useragents, urls_to_test)
fb_test
# Out:
#                           robotstxt_url user_agent   url_path  can_fetch
# 0   https://www.facebook.com/robots.txt          *          /      False
# 1   https://www.facebook.com/robots.txt          *       /bbc      False
# 2   https://www.facebook.com/robots.txt          *    /groups      False
# 3   https://www.facebook.com/robots.txt          *  /hashtag/      False
# 4   https://www.facebook.com/robots.txt   Applebot          /       True
# ..                                  ...        ...        ...        ...
# 79  https://www.facebook.com/robots.txt  seznambot  /hashtag/       True
# 80  https://www.facebook.com/robots.txt      teoma          /       True
# 81  https://www.facebook.com/robots.txt      teoma       /bbc       True
# 82  https://www.facebook.com/robots.txt      teoma    /groups       True
# 83  https://www.facebook.com/robots.txt      teoma  /hashtag/       True
#
# [84 rows x 4 columns]

# %%
fb_test.query('url_path== "/"')
# Out:
#                           robotstxt_url                 user_agent url_path
# 0   https://www.facebook.com/robots.txt                          *        /  \
# 4   https://www.facebook.com/robots.txt                   Applebot        /
# 8   https://www.facebook.com/robots.txt                    Bingbot        /
# 12  https://www.facebook.com/robots.txt                 Discordbot        /
# 16  https://www.facebook.com/robots.txt                  Googlebot        /
# 20  https://www.facebook.com/robots.txt            Googlebot-Image        /
# 24  https://www.facebook.com/robots.txt                LinkedInBot        /
# 28  https://www.facebook.com/robots.txt                   Naverbot        /
# 32  https://www.facebook.com/robots.txt               Pinterestbot        /
# 36  https://www.facebook.com/robots.txt  Screaming Frog SEO Spider        /
# 40  https://www.facebook.com/robots.txt                      Slurp        /
# ...

# %%
adv.robotstxt_to_df(['https://example.com/robots.txt',
                 'https://example.com/robots.txt',
                 'https://example.com/robots.txt'],
                output_file='robots_output_file.jl')
# Out:
# 2023-04-22 09:53:56,574 | INFO | robotstxt.py:381 | robotstxt_to_df | Getting: https://example.com/robots.txt
# 2023-04-22 09:53:56,577 | INFO | robotstxt.py:381 | robotstxt_to_df | Getting: https://example.com/robots.txt
# 2023-04-22 09:53:56,578 | INFO | robotstxt.py:381 | robotstxt_to_df | Getting: https://example.com/robots.txt

# %%
import pandas as pd

# %%
robotsfiles_df = pd.read_json('robots_output_file.jl', lines=True)

# %%
robotsfiles_df
# Out:
#                       errors                   robotstxt_url
# 0  HTTP Error 404: Not Found  https://example.com/robots.txt  \
# 1  HTTP Error 404: Not Found  https://example.com/robots.txt
# 2  HTTP Error 404: Not Found  https://example.com/robots.txt
#
#               download_date
# 0  2023-04-22T13:53:57.057Z
# 1  2023-04-22T13:53:57.146Z
# 2  2023-04-22T13:53:57.174Z

# %%
#### USING SITEMAP ######
adv.sitemap_to_df('https://www.salesforce.com/robots.txt', recursive=False)
# Out:
# 2023-04-22 09:56:03,438 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.salesforce.com/sitemap.xml
# 2023-04-22 09:56:05,156 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.salesforce.com/ap/sitemap.xml
# 2023-04-22 09:56:06,367 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.salesforce.com/au/sitemap.xml
# 2023-04-22 09:56:07,016 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.salesforce.com/br/sitemap.xml
# 2023-04-22 09:56:07,722 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.salesforce.com/ca/sitemap.xml
# 2023-04-22 09:56:08,290 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.salesforce.com/cn/sitemap.xml
# 2023-04-22 09:56:08,885 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.salesforce.com/de/sitemap.xml
# 2023-04-22 09:56:09,388 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.salesforce.com/dk/sitemap.xml
# ...

# %%
bbc_sitemap = adv.sitemap_to_df('https://www.bbc.com/sitemaps/https-sitemap-com-archive-1.xml')
bbc_sitemap.head(10)
# Out:
# 2023-04-22 09:58:55,554 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.bbc.com/sitemaps/https-sitemap-com-archive-1.xml
#                                                  loc
# 0  https://www.bbc.com/arabic/middleeast/2009/06/...  \
# 1  https://www.bbc.com/arabic/middleeast/2009/06/...
# 2  https://www.bbc.com/arabic/business/2009/06/09...
# 3  https://www.bbc.com/arabic/multimedia/2009/06/...
# 4  https://www.bbc.com/arabic/business/2009/06/09...
# 5  https://www.bbc.com/arabic/multimedia/2009/06/...
# 6  https://www.bbc.com/arabic/middleeast/2009/06/...
# 7  https://www.bbc.com/arabic/sports/2009/06/0906...
# 8  https://www.bbc.com/arabic/sports/2009/06/0906...
# 9  https://www.bbc.com/arabic/worldnews/2009/06/0...
#
#                     lastmod
# 0 2009-06-20 14:10:48+00:00  \
# 1 2009-06-20 21:07:43+00:00
# 2 2009-06-22 12:41:48+00:00
# 3 2009-06-24 15:27:24+00:00
# 4 2009-06-18 15:32:54+00:00
# 5 2009-06-25 09:46:39+00:00
# 6 2009-06-23 13:10:56+00:00
# ...

# %%
nyt_news = adv.sitemap_to_df('https://www.nytimes.com/sitemaps/new/news.xml.gz')
print(nyt_news.shape)
nyt_news
# Out:
# 2023-04-22 10:00:03,701 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.nytimes.com/sitemaps/new/news-2.xml.gz
# 2023-04-22 10:00:03,872 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.nytimes.com/sitemaps/new/news-5.xml.gz
# 2023-04-22 10:00:03,917 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.nytimes.com/sitemaps/new/news-6.xml.gz
# 2023-04-22 10:00:03,994 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.nytimes.com/sitemaps/new/news-1.xml.gz
# 2023-04-22 10:00:04,110 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.nytimes.com/sitemaps/new/news-4.xml.gz
# 2023-04-22 10:00:04,173 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.nytimes.com/sitemaps/new/news-7.xml.gz
# 2023-04-22 10:00:04,179 | INFO | sitemaps.py:536 | sitemap_to_df | Getting https://www.nytimes.com/sitemaps/new/news-3.xml.gz
# ...

# %%
import advertools as adv

urls = ['https://netloc.com/path_1/path_2?price=10&color=blue#frag_1',
        'https://netloc.com/path_1/path_2?price=15&color=red#frag_2',
        'https://netloc.com/path_1/path_2/path_3?size=sm&color=blue#frag_1',
        'https://netloc.com/path_1?price=10&color=blue']
adv.url_to_df(urls)
# Out:
#                                                  url scheme      netloc
# 0  https://netloc.com/path_1/path_2?price=10&colo...  https  netloc.com  \
# 1  https://netloc.com/path_1/path_2?price=15&colo...  https  netloc.com
# 2  https://netloc.com/path_1/path_2/path_3?size=s...  https  netloc.com
# 3      https://netloc.com/path_1?price=10&color=blue  https  netloc.com
#
#                     path                query fragment   dir_1   dir_2
# 0         /path_1/path_2  price=10&color=blue   frag_1  path_1  path_2  \
# 1         /path_1/path_2   price=15&color=red   frag_2  path_1  path_2
# 2  /path_1/path_2/path_3   size=sm&color=blue   frag_1  path_1  path_2
# 3                /path_1  price=10&color=blue      NaN  path_1     NaN
#
#     dir_3 last_dir query_color query_price query_size
# 0     NaN   path_2        blue          10        NaN
# 1     NaN   path_2         red          15        NaN
# 2  path_3   path_3        blue         NaN         sm
# ...

# %%
import advertools as adv

vegetable_emoji = adv.emoji_search('cat')
vegetable_emoji.head()
# Out:
#   codepoint           status emoji                            name
# 0     1F63A  fully-qualified     😺                    grinning cat  \
# 1     1F638  fully-qualified     😸  grinning cat with smiling eyes
# 2     1F639  fully-qualified     😹           cat with tears of joy
# 3     1F63B  fully-qualified     😻     smiling cat with heart-eyes
# 4     1F63C  fully-qualified     😼              cat with wry smile
#
#                group sub_group
# 0  Smileys & Emotion  cat-face
# 1  Smileys & Emotion  cat-face
# 2  Smileys & Emotion  cat-face
# 3  Smileys & Emotion  cat-face
# 4  Smileys & Emotion  cat-face

# %%
text_list = ['I feel like playing basketball 🏀',
             'I like playing football ⚽⚽',
             'Not feeling like sports today']

emoji_summary = adv.extract_emoji(text_list)
emoji_summary
# print(emoji_summary.keys())
# Out:
# {'emoji': [['🏀'], ['⚽', '⚽'], []],
#  'emoji_text': [['basketball'], ['soccer ball', 'soccer ball'], []],
#  'emoji_flat': ['🏀', '⚽', '⚽'],
#  'emoji_flat_text': ['basketball', 'soccer ball', 'soccer ball'],
#  'emoji_counts': [1, 2, 0],
#  'emoji_freq': [(0, 1), (1, 1), (2, 1)],
#  'top_emoji': [('⚽', 2), ('🏀', 1)],
#  'top_emoji_text': [('soccer ball', 2), ('basketball', 1)],
#  'top_emoji_groups': [('Activities', 3)],
#  'top_emoji_sub_groups': [('sport', 3)],
#  'overview': {'num_posts': 3,
#   'num_emoji': 3,
#   'emoji_per_post': 1.0,
#   'unique_emoji': 2}}

# %%
emoji_summary['emoji_flat_text']
# Out:
# ['basketball', 'soccer ball', 'soccer ball']

# %%
emoji_summary['overview']
# Out:
# {'num_posts': 3, 'num_emoji': 3, 'emoji_per_post': 1.0, 'unique_emoji': 2}

# %%
text_list = ['This is the first #text.', 'Second #sentence is here.',
             'Hello, how are you?', 'This #sentence is the last #sentence']
hashtag_summary = adv.extract_hashtags(text_list)
hashtag_summary.keys()
# Out:
# dict_keys(['hashtags', 'hashtags_flat', 'hashtag_counts', 'hashtag_freq', 'top_hashtags', 'overview'])

# %%
posts = ['text before 123', '123,456 text after', 'phone 333-444-555',
'multiple 123,456 and 123.456.789']
number_summary = adv.extract_numbers(posts)
number_summary.keys()
# Out:
# dict_keys(['numbers', 'numbers_flat', 'number_counts', 'number_freq', 'top_numbers', 'overview'])

# %%
number_summary['numbers']
# Out:
# [['123'], ['123,456'], ['333-444-555'], ['123,456', '123.456.789']]

# %%
number_summary['overview']
# Out:
# {'num_posts': 4,
#  'num_numbers': 5,
#  'numbers_per_post': 1.25,
#  'unique_numbers': 4}

# %%
adv.stopwords.keys()
# Out:
# dict_keys(['arabic', 'azerbaijani', 'bengali', 'catalan', 'chinese', 'croatian', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'greek', 'hebrew', 'hindi', 'hungarian', 'indonesian', 'irish', 'italian', 'japanese', 'kazakh', 'nepali', 'norwegian', 'persian', 'polish', 'portuguese', 'romanian', 'russian', 'sinhala', 'spanish', 'swedish', 'tagalog', 'tamil', 'tatar', 'telugu', 'thai', 'turkish', 'ukrainian', 'urdu', 'vietnamese'])

# %%
print(sorted(adv.stopwords['english'])[:5])
# Out:
# ['a', 'about', 'above', 'across', 'after']

# %%
t = ['split me into length-n-words',
'commas, (parentheses) get removed!',
'commas within text remain $1,000, but not the trailing commas.']
adv.word_tokenize(t,3)
# Out:
# [['split me into', 'me into length-n-words'],
#  ['commas parentheses get', 'parentheses get removed'],
#  ['commas within text',
#   'within text remain',
#   'text remain $1,000',
#   'remain $1,000 but',
#   '$1,000 but not',
#   'but not the',
#   'not the trailing',
#   'the trailing commas']]

# %%
adv.crawl('https://www.salesforce.com',
          'salesforce_crawl_1.jl',
          custom_settings={'CONCURRENT_REQUESTS_PER_DOMAIN': 1})

# %%
crawldf = pd.read_json('salesforce_crawl_1.jl', lines=True)
crawldf
# Out:
#                           url
# 0  https://www.salesforce.com  \
#
#                                                title
# 0  Salesforce: The Customer Company - Salesforce....  \
#
#                                            meta_desc
# 0  Personalize every experience along the custome...  \
#
#                                 viewport charset
# 0  width=device-width, initial-scale=1.0   UTF-8  \
#
#                                                   h1
# 0  \n    \n    AI + Data + CRM. It all adds up to...  \
#
#                                                   h2
# 0  \n    \n    What's new at Salesforce?\n    \n@...  \
#
#                                                   h3
# 0  \n    \n    Get sales, service, or marketing s...  \
#
#                      canonical og:image:alt  ...
# 0  https://www.salesforce.com/               ...  \
#
#             resp_headers_expires              resp_headers_date
# 0  Sat, 22 Apr 2023 14:29:20 GMT  Sat, 22 Apr 2023 14:24:20 GMT  \
#
# ...

# %%
adv.crawl(
    'https://www.salesforce.com', 'output_file.jl', follow_links=True,

    custom_settings={
        'DOWNLOADER_MIDDLEWARES': {
            'rotating_proxies.middlewares.RotatingProxyMiddleware': 610,
            'rotating_proxies.middlewares.BanDetectionMiddleware': 620
        },
        'ROTATING_PROXY_LIST_PATH': 'proxies.txt',
    }
)

# %%
import pandas as pd
crawldf = pd.read_json('output_file.jl', lines=True)
crawldf.filter(regex='proxy').head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1]

# %%
adv.crawl(
    url_list='https://example.com',
    output_file='output.jl',
    custom_settings={
        'DEFAULT_REQUEST_HEADERS': {
            'Accept-Language': 'es',
            'Accept-Encoding': 'gzip, deflate'
        }
    }
)

# %%
crawldf = pd.read_json('output.jl', lines=True)
crawldf.filter(regex='request_headers_')
# Out:
#   request_headers_accept-language request_headers_accept-encoding
# 0                              es                   gzip, deflate  \
#
#   request_headers_user-agent
# 0          advertools/0.13.2

# %%
url_list = ['https://exmaple.com/A', 'https://exmaple.com/B',
            'https://exmaple.com/C', 'https://exmaple.com/D',
            'https://exmaple.com/E']

# %%
adv.crawl_headers(url_list, 'output_file1.jl')
import pandas as pd
crawl_df = pd.read_json('output_file1.jl', lines=True)

# %%
crawl_df
# Out:
#                      url          crawl_time  status  download_timeout
# 0  https://exmaple.com/A 2023-04-22 14:54:32     200               180  \
# 1  https://exmaple.com/E 2023-04-22 14:54:32     200               180
# 2  https://exmaple.com/C 2023-04-22 14:54:32     200               180
# 3  https://exmaple.com/B 2023-04-22 14:54:32     200               180
# 4  https://exmaple.com/D 2023-04-22 14:54:32     200               180
#
#   download_slot  download_latency  depth  protocol  body
# 0   exmaple.com          0.037997      0  HTTP/1.1   NaN  \
# 1   exmaple.com          0.090994      0  HTTP/1.1   NaN
# 2   exmaple.com          0.096001      0  HTTP/1.1   NaN
# 3   exmaple.com          0.099001      0  HTTP/1.1   NaN
# 4   exmaple.com          0.096024      0  HTTP/1.1   NaN
#
#    resp_headers_content-length  ... resp_headers_content-type
# 0                            0  ...                 text/html  \
# 1                            0  ...                 text/html
# ...

# %%
adv.crawl('https://www.salesforce.com',
              output_file='exampleSL.jl',
              follow_links=True,
              custom_settings={'LOG_FILE': 'exampleSl.log'})

# %%
logs_df = adv.crawllogs_to_df('example.log')

# %%
logs_df
# Out:
#                  time                        middleware  level   message
# 0 2023-04-22 10:58:51  scrapy.spidermiddlewares.offsite  DEBUG  Filtered  \
# 1 2023-04-22 10:58:51                scrapy.core.engine  DEBUG   Crawled
# 2 2023-04-22 10:58:51                scrapy.core.engine  DEBUG   Crawled
# 3 2023-04-22 10:58:51               scrapy.core.scraper  DEBUG   Scraped
#
#          domain method                                   url status referer
# 0  www.iana.org    GET  https://www.iana.org/domains/example    NaN     NaN  \
# 1           NaN    GET        https://example.com/robots.txt    404    None
# 2           NaN    GET                   https://example.com    200    None
# 3           NaN    NaN                   https://example.com    200     NaN
#
#   method_to redirect_to method_from redirect_from blocked_urls
# 0       NaN         NaN         NaN           NaN          NaN
# 1       NaN         NaN         NaN           NaN          NaN
# ...

# %%
logs_df = adv.crawllogs_to_df('example.log')

# %%
logs_df
# Out:
#                  time                        middleware  level   message
# 0 2023-04-22 10:58:51  scrapy.spidermiddlewares.offsite  DEBUG  Filtered  \
# 1 2023-04-22 10:58:51                scrapy.core.engine  DEBUG   Crawled
# 2 2023-04-22 10:58:51                scrapy.core.engine  DEBUG   Crawled
# 3 2023-04-22 10:58:51               scrapy.core.scraper  DEBUG   Scraped
#
#          domain method                                   url status referer
# 0  www.iana.org    GET  https://www.iana.org/domains/example    NaN     NaN  \
# 1           NaN    GET        https://example.com/robots.txt    404    None
# 2           NaN    GET                   https://example.com    200    None
# 3           NaN    NaN                   https://example.com    200     NaN
#
#   method_to redirect_to method_from redirect_from blocked_urls
# 0       NaN         NaN         NaN           NaN          NaN
# 1       NaN         NaN         NaN           NaN          NaN
# ...

# %%
use_serp = adv.serp_goog(key='AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg',
                         cx='c4fc391654b014f8a',
                         q='hotel', gl=['us', 'fr'])
# Out:
# 2023-04-23 09:35:17,877 | INFO | serp.py:728 | serp_goog | Requesting: q=hotel, cx=c4fc391654b014f8a, key=AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg, gl=us
# 2023-04-23 09:35:18,413 | INFO | serp.py:728 | serp_goog | Requesting: q=hotel, cx=c4fc391654b014f8a, key=AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg, gl=fr

# %%
use_serp
# Out:
#     gl searchTerms  rank                                              title
# 0   us       hotel     1  Hotel del Coronado | San Diego's Legendary Bea...  \
# 1   us       hotel     2           Sheraton Shantou Hotel | Marriott Bonvoy
# 2   us       hotel     3  HotelTonight: Last Minute Hotel Deals at Great...
# 3   us       hotel     4  Hotels.com - Deals & Discounts for Hotel Reser...
# 4   us       hotel     5  Marriott Bonvoy Hotels | Book Directly & Get E...
# 5   us       hotel     6  Booking.com | Official site | The best hotels,...
# 6   us       hotel     7  Four Seasons Hotels and Resorts | Luxury Hotel...
# 7   us       hotel     8                                  Hotel - Wikipedia
# 8   us       hotel     9  Stay At Hotel Emma | San Antonio Boutique Hote...
# 9   us       hotel    10  Hotel Wailea, Relais & Châteaux | Official Sit...
# 10  fr       hotel     1  Hotel del Coronado | San Diego's Legendary Bea...
# ...

# %%
serp_res = adv.serp_goog(q=['flights', 'tickets'], cr=['countryNP', 'countryIN'],
              cx='c4fc391654b014f8a', key='AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg')
# Out:
# 2023-04-23 09:38:02,537 | INFO | serp.py:728 | serp_goog | Requesting: q=flights, cx=c4fc391654b014f8a, key=AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg, cr=countryNP
# 2023-04-23 09:38:03,005 | INFO | serp.py:728 | serp_goog | Requesting: q=flights, cx=c4fc391654b014f8a, key=AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg, cr=countryIN
# 2023-04-23 09:38:03,447 | INFO | serp.py:728 | serp_goog | Requesting: q=tickets, cx=c4fc391654b014f8a, key=AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg, cr=countryNP
# 2023-04-23 09:38:03,890 | INFO | serp.py:728 | serp_goog | Requesting: q=tickets, cx=c4fc391654b014f8a, key=AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg, cr=countryIN

# %%
serp_res
# Out:
#            cr searchTerms  rank
# 0   countryNP     flights     1  \
# 1   countryNP     flights     2
# 2   countryNP     flights     3
# 3   countryNP     flights     4
# 4   countryNP     flights     5
# 5   countryNP     flights     6
# 6   countryNP     flights     7
# 7   countryNP     flights     8
# 8   countryNP     flights     9
# 9   countryNP     flights    10
# 10  countryIN     flights     1
# 11  countryIN     flights     2
# 12  countryIN     flights     3
# 13  countryIN     flights     4
# 14  countryIN     flights     5
# 15  countryIN     flights     6
# 16  countryIN     flights     7
# 17  countryIN     flights     8
# 18  countryIN     flights     9
# 19  countryIN     flights    10
# 20  countryNP     tickets     1
# 21  countryNP     tickets     2
# 22  countryNP     tickets     3
# 23  countryNP     tickets     4
# 24  countryNP     tickets     5
# 25  countryNP     tickets     6
# 26  countryNP     tickets     7
# 27  countryNP     tickets     8
# ...

# %%
serp_res = adv.serp_youtube(q=['drums', 'horses'],
              key='AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg')
# Out:
# 2023-04-23 09:46:14,385 | INFO | serp.py:1163 | serp_youtube | Requesting: key=AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg, q=drums
# 2023-04-23 09:46:14,871 | INFO | serp.py:1163 | serp_youtube | Requesting: key=AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg, q=horses
# 2023-04-23 09:46:15,354 | INFO | serp.py:466 | youtube_video_details | Requesting: video details
# 2023-04-23 09:46:15,535 | INFO | serp.py:498 | youtube_channel_details | Requesting: channel details

# %%
serp_res
# Out:
#         q                        queryTime  rank
# 0   drums 2023-04-23 13:46:15.351273+00:00     1  \
# 1   drums 2023-04-23 13:46:15.351273+00:00     2
# 2   drums 2023-04-23 13:46:15.351273+00:00     3
# 3   drums 2023-04-23 13:46:15.351273+00:00     4
# 4   drums 2023-04-23 13:46:15.351273+00:00     5
# 5  horses 2023-04-23 13:46:15.351273+00:00     1
# 6  horses 2023-04-23 13:46:15.351273+00:00     2
# 7  horses 2023-04-23 13:46:15.351273+00:00     3
# 8  horses 2023-04-23 13:46:15.351273+00:00     4
# 9  horses 2023-04-23 13:46:15.351273+00:00     5
#
#                                                title
# 0  BABY SHARK DANCE | Drum cover | Amazing Child ...  \
# 1  SHAMANIC DRUMS + DEEP TRANCE HUMMING MEDITATIO...
# 2  1 Day vs 10 Years of Playing the Drum Set arou...
# 3           Eye of the Tiger - Drum Cover - Survivor
# 4     13 Levels of Drumming: Easy to Complex | WIRED
# 5  PnB Rock, Kodak Black &amp; A Boogie – Horses ...
# ...

# %%
serp_res = adv.knowledge_graph(query='google'
              , key='AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg')
# Out:
# 2023-04-23 09:53:45,550 | INFO | knowledge_graph.py:191 | single_request | Requesting: key=AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg, query=google

# %%
serp_res
# Out:
# Empty DataFrame
# Columns: [query_time]
# Index: []

# %%
youtube_obj = adv.youtube_video_details(key="AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg", vid_ids='Fxl6_hYjQyQ')
# Out:
# 2023-04-23 11:03:33,329 | INFO | serp.py:466 | youtube_video_details | Requesting: video details

# %%
youtube_obj
# Out:
#             kind                         etag           id
# 0  youtube#video  Y96nfJY1C8E7nj0MkKK5-damXNk  Fxl6_hYjQyQ  \
#
#                                              snippet
# 0  {'publishedAt': '2013-02-17T12:03:49Z', 'chann...  \
#
#                                       contentDetails
# 0  {'duration': 'PT57M39S', 'dimension': '2d', 'd...  \
#
#                                               status
# 0  {'uploadStatus': 'processed', 'privacyStatus':...  \
#
#                                           statistics
# 0  {'viewCount': '792061', 'likeCount': '7786', '...  \
#
#                                               player
# 0  {'embedHtml': '<iframe width="480" height="360...  \
#
#                                         topicDetails recordingDetails  ...
# 0  {'topicCategories': ['https://en.wikipedia.org...               {}  ...  \
#
#   embeddable publicStatsViewable madeForKids  duration dimension definition
# ...

# %%
yt_obj = adv.youtube

# %%
yt_channels = yt_obj.channels_list(key="AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg",part='snippet,id,contentDetails',id='@Houseofhighlights')

# %%
yt_channels
# Out:
#                           kind                         etag  totalResults
# 0  youtube#channelListResponse  RuuXzTIr0OoDqI4S0RU6n4FqKEM             0  \
#
#    resultsPerPage                 param_part            param_id
# 0               5  snippet,id,contentDetails  @Houseofhighlights  \
#
#   param_maxResults param_pageToken                        queryTime
# 0             None            None 2023-04-23 16:05:34.609478+00:00

# %%
yt_playlist = yt_obj.playlist_items_list(key="AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg", part="id,snippet",playlistId="PLAaPOSUfBy-wncjHATcpeRip14dC0EHua")

# %%
yt_playlist
# Out:
#                                kind                         etag
# 0  youtube#playlistItemListResponse  IZgjkavzch3pXFMK57c5qsVDCfM  \
# 1  youtube#playlistItemListResponse  IZgjkavzch3pXFMK57c5qsVDCfM
# 2  youtube#playlistItemListResponse  IZgjkavzch3pXFMK57c5qsVDCfM
# 3  youtube#playlistItemListResponse  IZgjkavzch3pXFMK57c5qsVDCfM
# 4  youtube#playlistItemListResponse  IZgjkavzch3pXFMK57c5qsVDCfM
#
#                                                   id
# 0  UExBYVBPU1VmQnktd25jakhBVGNwZVJpcDE0ZEMwRUh1YS...  \
# 1  UExBYVBPU1VmQnktd25jakhBVGNwZVJpcDE0ZEMwRUh1YS...
# 2  UExBYVBPU1VmQnktd25jakhBVGNwZVJpcDE0ZEMwRUh1YS...
# 3  UExBYVBPU1VmQnktd25jakhBVGNwZVJpcDE0ZEMwRUh1YS...
# 4  UExBYVBPU1VmQnktd25jakhBVGNwZVJpcDE0ZEMwRUh1YS...
#
#         snippet.publishedAt         snippet.channelId
# 0 2023-04-14 05:34:12+00:00  UCSJqe-jYefd-G3NwjMNGn9w  \
# 1 2022-10-25 09:26:57+00:00  UCSJqe-jYefd-G3NwjMNGn9w
# 2 2022-07-04 15:10:17+00:00  UCSJqe-jYefd-G3NwjMNGn9w
# ...

# %%
get_hash =  yt_playlist['snippet.description']

# %%
get_hash
# Out:
# 0    antent - first snow\n\nfollow our playlists fo...
# 1    Probably my favorite track from Bill. His geni...
# 2    if you want to support me: https://ko-fi.com/c...
# 3    Anime: Haikyuu!! To The Top | Haikyuu!! To The...
# 4    🎶 Listen this music on spotify: https://open.s...
# Name: snippet.description, dtype: object

# %%
get_hash = get_hash.apply(lambda s: adv.extract_emoji(s))

# %%
get_hash
# Out:
# 0    {'emoji': [[], [], [], [], [], [], [], [], [],...
# 1    {'emoji': [[], [], [], [], [], [], [], [], [],...
# 2    {'emoji': [[], [], [], [], [], [], [], [], [],...
# 3    {'emoji': [[], [], [], [], [], [], [], [], [],...
# 4    {'emoji': [['🎶'], [], [], [], [], [], [], [], ...
# Name: snippet.description, dtype: object

# %%
yt_dev = yt_obj.captions_list(key="AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg",part='snippet',videoId='Fxl6_hYjQyQ')

# %%
yt_dev
# Out:
#                           kind                         etag
# 0  youtube#captionListResponse  9OXJ1XNIo3zbYJC4T1LGtzyqstw  \
#
#                                                   id snippet.videoId
# 0  AUieDaYk9uiH98lbcqmAsLMgtZ9SI3RkeBp1ao5T4-sV_N...     Fxl6_hYjQyQ  \
#
#            snippet.lastUpdated snippet.trackKind snippet.language
# 0  2020-10-21T06:29:14.317776Z               asr               en  \
#
#   snippet.name snippet.audioTrackType  snippet.isCC  snippet.isLarge
# 0                             unknown         False            False  \
#
#    snippet.isEasyReader  snippet.isDraft  snippet.isAutoSynced snippet.status
# 0                 False            False                 False        serving  \
#
#   param_part param_videoId param_maxResults param_pageToken
# 0    snippet   Fxl6_hYjQyQ             None            None  \
#
#                          queryTime
# 0 2023-04-26 16:14:04.072114+00:00

# %%
yt_cat = yt_obj.i18n_regions_list(key='AIzaSyDAfhTl8ipspvo1c5qbuVf4HT2PBuxymRg', part='snippet')

# %%
yt_cat
# Out:
#                                kind                         etag  id
# 0    youtube#i18nRegionListResponse  W4plLuxq5WpK6wjKPBYqtBHp-Kg  AE  \
# 1    youtube#i18nRegionListResponse  W4plLuxq5WpK6wjKPBYqtBHp-Kg  BH
# 2    youtube#i18nRegionListResponse  W4plLuxq5WpK6wjKPBYqtBHp-Kg  DZ
# 3    youtube#i18nRegionListResponse  W4plLuxq5WpK6wjKPBYqtBHp-Kg  EG
# 4    youtube#i18nRegionListResponse  W4plLuxq5WpK6wjKPBYqtBHp-Kg  IQ
# ..                              ...                          ...  ..
# 104  youtube#i18nRegionListResponse  W4plLuxq5WpK6wjKPBYqtBHp-Kg  TW
# 105  youtube#i18nRegionListResponse  W4plLuxq5WpK6wjKPBYqtBHp-Kg  CY
# 106  youtube#i18nRegionListResponse  W4plLuxq5WpK6wjKPBYqtBHp-Kg  KH
# 107  youtube#i18nRegionListResponse  W4plLuxq5WpK6wjKPBYqtBHp-Kg  LI
# 108  youtube#i18nRegionListResponse  W4plLuxq5WpK6wjKPBYqtBHp-Kg  PG
#
#     snippet.gl          snippet.name param_part param_maxResults
# 0           AE  United Arab Emirates    snippet             None  \
# ...

# %%
auth_params = {
    'app_key': 'FObWAz6gSk8LrKH1RvXcXeEYQ',
    'app_secret': 'pdYYnMwxMtG4cN5m5vTzmrw0s8LSgeT2qx8EFAKx1EaiiBRGUR',
    # 'oauth_token': '1610624799038148610-glQlqQEoj9D5lleH2ds8zS115ppw3t',
    # 'oauth_token_secret': 'qBn4Bvzud4kLQsASOFWoxrDhFsodoDP0MIC40HcTxZjHY'
    'access_token': 'AAAAAAAAAAAAAAAAAAAAAErbmwEAAAAAOnDpT0crRSWc9i%2BRJALTuINdpRs%3DqEdVJnu28SrSivF5KaYwjCaEsAN6WLttjzPzMNf5xkL2kzBR4M',
    # 'client_id': 'YWJhMXdBV2pIcmZZYXFMRFdHd3k6MTpjaQ',
    # 'client_secret': 'hOGMzYwZ7CmVO0moTeqSWAqvd5crNgDWY8mlwmA1COiFAkrMSx'
}
adv.twitter.set_auth_params(**auth_params,oauth_version=2,token_type='bearer',api_version='2.0')
# check_auth = adv.twitter.authenticate()
# print(check_auth)

# %%
input_keyword = "avengers"
count_data = 200
df = adv.twitter.get_followers_list(screen_name='GerWholesale')
# Out:
# 2023-04-26 12:08:03,652 | INFO | twitter.py:246 | wrapper | get_followers_list | Requesting: count=200, max_id=None, screen_name=GerWholesale
# ---------------------------------------------------------------------------
# TwythonError                              Traceback (most recent call last)
# Cell In[134], line 3
#       1 input_keyword = "avengers"
#       2 count_data = 200
# ----> 3 df = adv.twitter.get_followers_list(screen_name='GerWholesale')
#
# File c:\Users\thesm\OneDrive\Desktop\advertools\venv\lib\site-packages\advertools\twitter.py:250, in make_dataframe.<locals>.wrapper(count, max_id, *args, **kwargs)
#     245     args_log = ', '.join(args)
#     246     logging.info(msg=fname + ' | ' + 'Requesting: ' +
#     247                  'count=' + str(count) + ', max_id=' +
#     248                  str(max_id) + ', ' + kwargs_log + args_log)
# --> 250     resp = func(count=count,
#     251                 max_id=max_id,
#     252                 cursor=cursor,
# ...

# %%
# Out:
# Empty DataFrame
# Columns: [query_time]
# Index: []
